# %%
import requests

url = "https://api.movidesk.com/public/v1/tickets?token=a8d83bcc-5d05-44ed-be76-cd872d880dd2&$select=id,subject,createdDate,clients,owner,chatWaitingTime,chatTalkTime,lifetimeWorkingTime&$expand=clients($select=businessName,email),owner($select=businessName,email)"
response = requests.get(url)

if response.status_code == 200:
    tickets = response.json()
    for ticket in tickets:
        print(ticket)
else:
    print(f"Erro ao recuperar os dados: {response.status_code}")
# Out:
# {'lifeTimeWorkingTime': 62234, 'chatTalkTime': None, 'chatWaitingTime': None, 'createdDate': '2020-02-19T18:57:07.7364979', 'subject': 'Teste 123 ', 'id': 2, 'owner': {'email': 'tnascimento@bernhoeft.com.br', 'businessName': 'Tatiana Rios'}, 'clients': [{'email': 'fabio.guths@movidesk.com', 'businessName': 'Movidesk'}]}
# {'lifeTimeWorkingTime': 62234, 'chatTalkTime': None, 'chatWaitingTime': None, 'createdDate': '2020-02-19T19:25:50.9030741', 'subject': 'Teste 2 ', 'id': 3, 'owner': {'email': None, 'businessName': 'Fábio | Movidesk'}, 'clients': [{'email': None, 'businessName': 'Fábio | Movidesk'}]}
# {'lifeTimeWorkingTime': 62234, 'chatTalkTime': None, 'chatWaitingTime': None, 'createdDate': '2020-02-19T19:27:16.8017879', 'subject': 'Teste 3 ', 'id': 4, 'owner': {'email': None, 'businessName': 'Fábio | Movidesk'}, 'clients': [{'email': 'fabio.guths@movidesk.com', 'businessName': 'Movidesk'}]}
# ...
